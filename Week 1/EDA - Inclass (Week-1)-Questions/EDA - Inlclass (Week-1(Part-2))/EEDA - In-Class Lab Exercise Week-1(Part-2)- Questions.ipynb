# %% [markdown]
# <table align="center" width=100%>
#     <tr>
#         <td width="15%">
#             <img src="in_class.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                     <b> Inclass - Lab <br>Week-1(Part-2)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### About the dataset (Adult Income Data)
#
# The dataset contains information about the individuals' age, gender, and several attributes affecting the income of a person. <br> Attribute information:
#
# **age:** Age of an individual
#
# **workclass:** Working class of the individual
#
# **fnlwgt:** Weights based on the demographic characteristics
#
# **education:** Highest education of the individual
#
# **education.num:** Education encoded with unique numbers
#
# **marital.status:** Marital status of the individual
#
# **occupation:** Occupation of the individual
#
# **relationship:** Relation of the individual in the family
#
# **race:** Race of the individual
#
# **sex:** Gender of the individual
#
# **capital.gain:** Gain amount of the individual
#
# **capital.loss:** Loss amount of the individual
#
# **hours.per.week:** Working hours per week
#
# **native.country:** The native country of the individual
#
# **income:** Income of the individual

# %% [markdown]
# ##  Table of Content
#
# 1. **[Quantitative and Quantitative Analysis](#quan)**
# 2. **[Categorical and Quantitative Analysis](#catquan)**
# 3. **[Categorical and Categorical Analysis](#cat)**

# %% [markdown]
# **Import the required libraries**

# %%
# type your code here

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# #### Load the adult dataset and check the first five observations

# %%
# type your code here

df_adult = pd.read_csv('adult.csv')
df_adult.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# ...

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# <a id="quan"> </a>
# ## 1. Quantitative and Quantitative Analysis

# %%
# Graph
#kde,distplot --> univariate lineplot,scatter - > bi Variate

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>1. Is there any effect of a person's age on the working hours</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here

sns.scatterplot(data = df_adult,x='age',y='hours.per.week')
plt.xlabel('Age')
plt.ylabel('Working Hours Per Week')
plt.show()

# %%
# No effect of age on working hours

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>2. Analyze the trend of the capital gain amount for different educational qualifications</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here

#Line Plot can be used when asked for trends

sns.lineplot(data = df_adult,x='education.num',y='capital.gain')
plt.show()

# %%
# With the education.num increase , capital .gain also increases

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>3. Check the effect of working hours of individuals on capital gain </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here

sns.scatterplot(data = df_adult,x='hours.per.week',y='capital.gain')
plt.show()

# %%
# No effect of hours.per.week on capital.gain

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>4.  Find the trend in the average working hours corresponding to the age of an individual</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here

sns.lineplot(data = df_adult,x='age',y='hours.per.week')
plt.show()

# %%
# There is equal wrking hours between the age 29 to 55 and then the slope drops when the age increases

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>5. Check the distribution of the average capital loss corresponding to the age</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here

df_adult.groupby('age')['capital.loss'].mean().plot(kind = 'line')
plt.show()

# %%
# No much effect of age on capital gain and capital loss

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>6. Is there a negative relation between capital gain and age?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here

sns.scatterplot(data = df_adult,x='age',y='capital.gain')
plt.show()

# %%
# There is no negative relation between capital and age

# %% [markdown]
# <a id="catquan"> </a>
# ## 2. Categorical and Quantitative Analysis

# %%
#graph
#box,bar,violin,swarm,strip

#avg - bar
#distribution - violin
# COmpare - box/bar

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>7. Compare the average age with levels of income </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df_adult.head(2)
# Out:
#    age workclass  fnlwgt education  education.num marital.status  \
# 0   90         ?   77053   HS-grad              9        Widowed
# 1   82   Private  132870   HS-grad              9        Widowed
#
#         occupation   relationship   race     sex  capital.gain  capital.loss  \
# 0                ?  Not-in-family  White  Female             0          4356
# 1  Exec-managerial  Not-in-family  White  Female             0          4356
#
#    hours.per.week native.country income
# 0              40  United-States  <=50K
# 1              18  United-States  <=50K

# %%
# type your code here

df_adult.groupby('income')['age'].mean().plot(kind ='bar')
plt.xlabel('Income')
plt.ylabel('Age')
plt.show()

# %%
# Higher age Higher income

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>8. Check the distribution of working hours with respect to the gender of the individual</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here

sns.violinplot(data = df_adult,y='sex',x='hours.per.week')
plt.show()

# %%
# Hours per week not much effected based on Gender

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>9. Compare the income of individuals based on their education</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here

sns.barplot(data = df_adult,x='income',y='education.num')
plt.show()

# %%
sns.boxplot(data = df_adult,x='income',y='education.num')
plt.show()

# %%
# To get income > 50k , u should have education >12

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>10. Find the average age of males and females</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
df_adult.groupby('sex')['age'].mean().plot(kind ='bar')
plt.xlabel('Sex')
plt.ylabel('Age')
plt.show()

# %%
df_adult.groupby('sex')['age'].mean()
# Out:
# sex
# Female    36.858230
# Male      39.433547
# Name: age, dtype: float64

# %%
# Average age of male is 39.43 and average age of female is 36.85

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>11. Compare the distribution of working hours for the distinct classes of income
#  </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here

sns.violinplot(data =df_adult,x='hours.per.week',y='income')
plt.show()

# %%
# Less hours of work , less salary

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>12. Identify the positively skewed distributions of age based on the gender and race of the individual
#  </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here

sns.violinplot(data =df_adult,x='age',y='race',hue='sex',split='age')
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>13. Compare the working hours for each working class</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here

plt.figure(figsize = (14,6))
sns.boxplot(data =df_adult,x='hours.per.week',y='workclass')
plt.show()

# %%
# Self Employed peoples are wrking more hours when compaed to others
# State Govt poeople are wrking less as its fixed time
#Private people are also less wrking hours but there are some private sector people(outliers) are working more hours

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>14. Compare the weightage based on demographic characteristics by gender</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here

sns.boxplot(data =df_adult,x='sex',y='fnlwgt')
plt.show()

# %%
# Male Dominant

# %% [markdown]
# <a id="cat"> </a>
# ## 3. Categorical and Categorical Analysis

# %%
# Cat VS cat graph

#Countplot with hue
#crosstab

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>15. Study the variation in income by gender</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here

sns.countplot(data=df_adult,x='income',hue='sex')
plt.show()

# %%
pd.crosstab(df_adult['income'],df_adult['sex']).plot.bar()
plt.show()

# %%
pd.crosstab(df_adult['income'],df_adult['sex'],normalize ='index')*100 # Percentage normlaize based on index
# Out:
# sex        Female       Male
# income
# <=50K   38.802589  61.197411
# >50K    15.036347  84.963653

# %%
pd.crosstab(df_adult['income'],df_adult['sex'],normalize ='columns')*100 # Percentage normlaize based on column

#Out of 100 , 89% female are earning <=50k and 10% are earning above 50k
# Out:
# sex        Female       Male
# income
# <=50K   89.053941  69.426342
# >50K    10.946059  30.573658

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>16. Compare the income by race</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here

sns.countplot(data = df_adult,x= df_adult['race'],hue=df_adult['income'])
plt.show()

# %%
# White race are earning more than the other races

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>17. Is there an all male profession according to the data?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here

#Profession with sex
plt.figure(figsize = (15,6))
sns.countplot(x=df_adult['occupation'], hue=df_adult['sex'])
plt.xticks(rotation=45)
plt.show()

# %%
# ARmed -Forces are Male dominant

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>18. How does income vary with working class?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df_adult.head(1)
# Out:
#    age workclass  fnlwgt education  education.num marital.status occupation  \
# 0   90         ?   77053   HS-grad              9        Widowed          ?
#
#     relationship   race     sex  capital.gain  capital.loss  hours.per.week  \
# 0  Not-in-family  White  Female             0          4356              40
#
#   native.country income
# 0  United-States  <=50K

# %%
# type your code here

plt.figure(figsize = (13,6))
sns.countplot(data = df_adult,x='workclass',hue='income')
plt.show()

# %%
# Private working earns more thaan the other in Both Income Category classes

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>19. How is income related to marital status?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here

plt.figure(figsize = (13,6))
plt.xticks(rotation=45)
sns.countplot(data = df_adult,x='marital.status',hue='income')
plt.show()

# %%
# In all the marital.status , Most of the peeople are earning <=50k

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>20. Compare the income for different occupations</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here

plt.figure(figsize = (13,6))
plt.xticks(rotation=45)
sns.countplot(data = df_adult,x='occupation',hue='income')
plt.show()

# %%
# There is some relation between income and occupation
