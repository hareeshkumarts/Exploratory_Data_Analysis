# %% [markdown]
# <table align="center" width=100%>
#     <tr>
#         <td width="15%">
#             <img src="in_class.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                     <b> Inclass - Lab <br>(Week-1(Part-1) )
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### About the dataset (Health Insurance Data)
#
# The dataset contains information about 1300 individuals regarding insurance charges. The data contains an individual's basic information like age, sex, bmi, the region of residence and so on.
#
# Attribute Information:
#
# **age**: Age of the individual
#
# **gender**: Gender of the individual
#
# **bmi**: Body mass index of the individual
#
# **bp**: Systolic blood pressure in mm/hg
#
# **children**: Number of children of the individual
#
# **smoker**: Individual is smoker or not
#
# **region**: Individual's region of residence
#
# **medical_cost**: Individual's medical costs billed by the insurance company

# %% [markdown]
# ##  Table of Content
#
# 1. **[Univariate Analysis](#uni)**
# 2. **[Multivariate Analysis](#multi)**
# 3. **[Handle Non-Numeric Data](#cat)**
# 4. **[Normalization](#norm)**
# 5. **[Transformation Techniques](#trans)**

# %% [markdown]
# **Import the required libraries**

# %%
# import your code here
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# #### Load the health insurance dataset and check the first five observations

# %%
# import your code here
df_insurance = pd.read_csv('C:/Users/hareeshkumar.s/Downloads/health_insurance.csv')
df_insurance.head(5)
# Out:
#    age gender     bmi  bp   children     region      smoker  medical_cost
# 0   23      M  31.900  157         0  southwest      smoker   16884.92400
# 1   20      F  36.770  160         1  southeast  non-smoker    1725.55230
# 2   33      F  35.000  145         3  southeast  non-smoker    4449.46200
# 3   37      F  23.705  153         0  northwest  non-smoker   21984.47061
# 4   36      F  27.880  156         0  northwest  non-smoker    3866.85520

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# <a id="uni"> </a>
# ## 1. Univariate Analysis

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>1. Are there any extreme observations present in 'bmi'? Support your answer with a plot
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# Best graph to find Outliers are kde and box plot

# %%
# import your code here
bmi_skew = df_insurance['bmi'].skew()
bmi_kurt = df_insurance['bmi'].kurt()

print('Skewness of bmi : ',bmi_skew)
print('Kurtosis of bmi : ',bmi_kurt)
# Out:
# Skewness of bmi :  0.2496769760401315
# Kurtosis of bmi :  0.16156780310996366

# %%
mean_bmi  = df_insurance['bmi'].mean()
median_bmi = df_insurance['bmi'].median()

print('Mean of BMI : ',mean_bmi)
print('Median of BMI : ',median_bmi)
# Out:
# Mean of BMI :  31.581396153846132
# Median of BMI :  31.645

# %%
sns.kdeplot(df_insurance['bmi'])
plt.xlabel('BMI')
plt.title('Identifying if there are any outliers in BMI Feature')
plt.show()

# %%
plt.boxplot(df_insurance['bmi'])
plt.title('Identifying if there are any outliers in BMI Feature')
plt.show()

# %%
# 1.As per Observation of the graph, we can say that there are extreme values present in the data
# 2.Skewness and Kurtosis is greater than Zero
# 3.Positively skewed and LeptoKurtic

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>2. Is the variable 'age' skewed? Support your answer with a plot and metric</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here

df_insurance['age'].skew()
# Out:
# 0.04359793424360781

# %%
sns.kdeplot(df_insurance['age'])
plt.show()

# %%
sns.boxplot(data= df_insurance,y='age')
plt.show()

# %%
# We can observe that the data is approximately normally skewed

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>3. What is the probability that the individuals have charged less than 25k for medical treatment? Support your answer with the plot</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here

df_insurance[df_insurance['medical_cost'] < 25000].shape
# Out:
# (1108, 8)

# %%
1108/1300
# Out:
# 0.8523076923076923

# %%
sns.distplot(df_insurance['medical_cost'],kde_kws=dict(cumulative=True))
plt.show()

# %%
#The probability that the individuals have charged less than 25k for medical treatment is 0.85

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>4. Draw the line for mean and median on the distribution plot and identify the type of skewness for BMI</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here

mean_bmi  = df_insurance['bmi'].mean()
median_bmi = df_insurance['bmi'].median()

print('Mean of BMI : ',mean_bmi)
print('Median of BMI : ',median_bmi)
# Out:
# Mean of BMI :  31.581396153846132
# Median of BMI :  31.645

# %%
sns.kdeplot(df_insurance['bmi'])
plt.axvline(mean_bmi,label = 'Mean',color ='red')
plt.axvline(median_bmi,label = 'Median',color ='yellow')
plt.legend()
plt.show()

# %%
df_insurance['bmi'].skew()
# Out:
# 0.2496769760401315

# %%
# Based on the skew values , we can say that its positively skewed

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>5. Visualize the distribution of medical cost using violin plot and describe its distribution</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here

sns.violinplot(df_insurance['medical_cost'])
plt.show()

# The medical cost is highly positively skewed

# %% [markdown]
# <a id="multi"> </a>
# ## 2. Multivariate Analysis

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>6. Is there any individual with age less than 30 and meadical cost greater than 40k?
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here

df_insurance[(df_insurance['age'] < 30) & (df_insurance['medical_cost'] > 40000)]
# Out:
#       age gender    bmi  bp   children     region  smoker  medical_cost
# 254    26      F  47.54  156         2  northeast  smoker    42112.2356
# 1009   25      F  55.58  152         1  northeast  smoker    44501.3982
# 1086   26      M  41.75  152         1  northeast  smoker    40904.1995

# %%
# There are 3 individuals whose age < 30 and medical cost > 40k

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>7. Does the scatter plot of BMI and medical cost reveal potential outliers?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here

sns.scatterplot(x='bmi',y='medical_cost',data=df_insurance)
plt.show()

# %%
# the scatter plot of BMI and medical cost reveal potential outliers
# There are some outliers

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>8. Determine the percentage variation in BMI for males and females
#
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here

male = df_insurance[df_insurance['gender'] == 'M']
female = df_insurance[df_insurance['gender'] == 'F']

# %%
male_per_variation = (male['bmi'].std() /male['bmi'].mean()) *100
male_per_variation
# Out:
# 20.11832417604717

# %%
female_per_variation = (female['bmi'].std() /female['bmi'].mean()) *100
female_per_variation
# Out:
# 20.12002883340287

# %%
female_per_variation - male_per_variation
# Out:
# 0.001704657355698913

# %%
# Male Percentahe Variation is 20.11 and Female Percentage Variation is 20.12

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>9. Which region has the highest number of males?
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# Category Vs Category : crosstab / count (hue)

# %%
# import your code here
df_male = df_insurance[df_insurance['gender'] == 'M']
df_male.groupby('region')['gender'].count()
# Out:
# region
# northeast    141
# northwest    166
# southeast    178
# southwest    158
# Name: gender, dtype: int64

# %%
pd.crosstab(df_insurance['region'],df_insurance['gender']).plot.bar()
plt.show()

# %%
sns.countplot(data = df_insurance , x = df_insurance['region'],hue=df_insurance['gender'])
# Out:
# <AxesSubplot:xlabel='region', ylabel='count'>

# %%
# We can observe that Southeast has the highest number of male

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>10. Analyze the pairwise relationship between the numeric variables
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here

sns.pairplot(df_insurance,height=3)
plt.show()

# %%
# From the graph, we can say that there is a linear relation with age and medical_cost

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>11. Are the medical costs affected by an individual's smoking habits?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here
#Numerical and Categorical comparison -->box,bar,violin,strip,swarm

sns.barplot(data = df_insurance,x = 'smoker',y='medical_cost')
plt.title('Smoker Habits VS Medical cost')
plt.show()

# %%
sns.boxplot(data = df_insurance,x = 'smoker',y='medical_cost')
plt.title('Smoker Habits VS Medical cost')
plt.show()

# %%
# People with somkers have high medical cost

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>12. Check if the region of residence and age of the individuals have an impact on the medical cost? </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here

# Categorical VS Numerical VS Numerical
# hue - Categorical - region

sns.scatterplot(x= df_insurance['age'],y=df_insurance['medical_cost'],hue = df_insurance['region'])
plt.show()

# %%
#  With increase in age , medical_cost increases
# Region does not have any effect on any of them

# %% [markdown]
# <a id="cat"> </a>
# ## 3. Handle Non-Numeric Data

# %%
df_insurance.head()
# Out:
#    age gender     bmi  bp   children     region      smoker  medical_cost
# 0   23      M  31.900  157         0  southwest      smoker   16884.92400
# 1   20      F  36.770  160         1  southeast  non-smoker    1725.55230
# 2   33      F  35.000  145         3  southeast  non-smoker    4449.46200
# 3   37      F  23.705  153         0  northwest  non-smoker   21984.47061
# 4   36      F  27.880  156         0  northwest  non-smoker    3866.85520

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>13. Create a dummy variable for each category in 'region'
#  </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here

pd.get_dummies(data = df_insurance['region'],drop_first=True)
# Out:
#       northwest  southeast  southwest
# 0             0          0          1
# 1             0          1          0
# 2             0          1          0
# 3             1          0          0
# 4             1          0          0
# ...         ...        ...        ...
# 1295          0          0          1
# 1296          0          0          0
# 1297          0          1          0
# 1298          1          0          0
# 1299          1          0          0
#
# [1300 rows x 3 columns]

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>14. Create a variable 'smoker_label' containing unique label for each category in the variable 'smoker'
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here

from sklearn.preprocessing import LabelEncoder

LE = LabelEncoder()

df_insurance['smoker_label'] = LE.fit_transform(df_insurance['smoker'])

df_insurance.head()
# Out:
#    age gender     bmi  bp   children     region      smoker  medical_cost  \
# 0   23      M  31.900  157         0  southwest      smoker   16884.92400
# 1   20      F  36.770  160         1  southeast  non-smoker    1725.55230
# 2   33      F  35.000  145         3  southeast  non-smoker    4449.46200
# 3   37      F  23.705  153         0  northwest  non-smoker   21984.47061
# 4   36      F  27.880  156         0  northwest  non-smoker    3866.85520
#
#    smoker_label
# 0             1
# 1             0
# 2             0
# 3             0
# 4             0

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>15. Create a variable which will contain the frequency of an individual's gender</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here

df_insurance['FE_Gender'] = df_insurance['gender'].replace(df_insurance['gender'].value_counts(normalize=True))

# %%
df_insurance.head()
# Out:
#    age gender     bmi  bp   children     region      smoker  medical_cost  \
# 0   23      M  31.900  157         0  southwest      smoker   16884.92400
# 1   20      F  36.770  160         1  southeast  non-smoker    1725.55230
# 2   33      F  35.000  145         3  southeast  non-smoker    4449.46200
# 3   37      F  23.705  153         0  northwest  non-smoker   21984.47061
# 4   36      F  27.880  156         0  northwest  non-smoker    3866.85520
#
#    smoker_label  FE_Gender
# 0             1   0.494615
# 1             0   0.505385
# 2             0   0.505385
# 3             0   0.505385
# 4             0   0.505385

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>16. Create a variable such that the value '1' indicates that the individual is a smoker and '0' indicates a non-smoker</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here

df_insurance['Replace_smoker'] = df_insurance['smoker'].map({'smoker' :1,'non-smoker' : 0 })

# %%
df_insurance.head()
# Out:
#    age gender     bmi  bp   children     region      smoker  medical_cost  \
# 0   23      M  31.900  157         0  southwest      smoker   16884.92400
# 1   20      F  36.770  160         1  southeast  non-smoker    1725.55230
# 2   33      F  35.000  145         3  southeast  non-smoker    4449.46200
# 3   37      F  23.705  153         0  northwest  non-smoker   21984.47061
# 4   36      F  27.880  156         0  northwest  non-smoker    3866.85520
#
#    smoker_label  FE_Gender  Replace_smoker
# 0             1   0.494615               1
# 1             0   0.505385               0
# 2             0   0.505385               0
# 3             0   0.505385               0
# 4             0   0.505385               0

# %% [markdown]
# <a id="norm"> </a>
# ## 4. Normalization

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>17. Transform BMI such that it will have mean zero and variance one</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df_insurance['bmi'].skew()
# Out:
# 0.2496769760401315

# %%
# import your code here

from sklearn.preprocessing import StandardScaler
mm = StandardScaler()

df_insurance['SS_BMI'] = mm.fit_transform(df_insurance[['bmi']])
df_insurance.head()
# Out:
#    age gender     bmi  bp   children     region      smoker  medical_cost  \
# 0   23      M  31.900  157         0  southwest      smoker   16884.92400
# 1   20      F  36.770  160         1  southeast  non-smoker    1725.55230
# 2   33      F  35.000  145         3  southeast  non-smoker    4449.46200
# 3   37      F  23.705  153         0  northwest  non-smoker   21984.47061
# 4   36      F  27.880  156         0  northwest  non-smoker    3866.85520
#
#      SS_BMI
# 0  0.050142
# 1  0.816583
# 2  0.538020
# 3 -1.239588
# 4 -0.582526

# %%
np.round(df_insurance['SS_BMI'].mean(),2),np.round(df_insurance['SS_BMI'].var(),2)
# Out:
# (-0.0, 1.0)

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>18. Check the range of 'age' and transform the values such that the range will be 1</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here
from sklearn.preprocessing import MinMaxScaler
min_max = MinMaxScaler()
df_insurance['MM_AGE'] = min_max.fit_transform(df_insurance[['age']])
df_insurance.head()
# Out:
#    age gender     bmi  bp   children     region      smoker  medical_cost  \
# 0   23      M  31.900  157         0  southwest      smoker   16884.92400
# 1   20      F  36.770  160         1  southeast  non-smoker    1725.55230
# 2   33      F  35.000  145         3  southeast  non-smoker    4449.46200
# 3   37      F  23.705  153         0  northwest  non-smoker   21984.47061
# 4   36      F  27.880  156         0  northwest  non-smoker    3866.85520
#
#      SS_BMI  MM_AGE
# 0  0.050142    0.08
# 1  0.816583    0.02
# 2  0.538020    0.28
# 3 -1.239588    0.36
# 4 -0.582526    0.34

# %%
range_age = df_insurance['age'].max() - df_insurance['age'].min()
range_mm_age = df_insurance['MM_AGE'].max() - df_insurance['MM_AGE'].min()

print("range of age : ",range_age)
print("range of age after Transformation :",range_mm_age)
# Out:
# range of age :  50
# range of age after Transformation : 1.0

# %% [markdown]
# <a id="trans"> </a>
# ## 5. Transformation Techniques

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>19. Check the skewness for 'medical_cost'. If the data is skewed, then use the appropriate technique to reduce the skewness in the data
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import your code here

df_insurance['medical_cost'].skew()
# Out:
# 1.5341854555059413

# %%
df_insurance['sqrt_medical_cost'] = np.sqrt(df_insurance['medical_cost'])
df_insurance.head()
# Out:
#    age gender     bmi  bp   children     region      smoker  medical_cost  \
# 0   23      M  31.900  157         0  southwest      smoker   16884.92400
# 1   20      F  36.770  160         1  southeast  non-smoker    1725.55230
# 2   33      F  35.000  145         3  southeast  non-smoker    4449.46200
# 3   37      F  23.705  153         0  northwest  non-smoker   21984.47061
# 4   36      F  27.880  156         0  northwest  non-smoker    3866.85520
#
#      SS_BMI  MM_AGE  sqrt_medical_cost
# 0  0.050142    0.08         129.942002
# 1  0.816583    0.02          41.539768
# 2  0.538020    0.28          66.704288
# 3 -1.239588    0.36         148.271611
# 4 -0.582526    0.34          62.184043

# %%
df_insurance['log_medical_cost'] = np.log(df_insurance['medical_cost'])
df_insurance.head()
# Out:
#    age gender     bmi  bp   children     region      smoker  medical_cost  \
# 0   23      M  31.900  157         0  southwest      smoker   16884.92400
# 1   20      F  36.770  160         1  southeast  non-smoker    1725.55230
# 2   33      F  35.000  145         3  southeast  non-smoker    4449.46200
# 3   37      F  23.705  153         0  northwest  non-smoker   21984.47061
# 4   36      F  27.880  156         0  northwest  non-smoker    3866.85520
#
#      SS_BMI  MM_AGE  sqrt_medical_cost  log_medical_cost
# 0  0.050142    0.08         129.942002          9.734176
# 1  0.816583    0.02          41.539768          7.453302
# 2  0.538020    0.28          66.704288          8.400538
# 3 -1.239588    0.36         148.271611          9.998092
# 4 -0.582526    0.34          62.184043          8.260197

# %%
print("Skewness of medical cost after sqrt  :",df_insurance['sqrt_medical_cost'].skew())
print("Skewness of medical cost after log : ",df_insurance['log_medical_cost'].skew())
# Out:
# Skewness of medical cost after sqrt  : 0.8034147811041793
# Skewness of medical cost after log :  -0.09331493541417475

# %%
sns.kdeplot(df_insurance['medical_cost'])
plt.show()
sns.kdeplot(df_insurance['sqrt_medical_cost'])
plt.show()
sns.kdeplot(df_insurance['log_medical_cost'])
plt.show()

# %%
#Taking log reduced the skewness more thaan sqrt Teachnique

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>20. Transform the 'log_medical_cost' values to the original scale and compare the 'medical_cost' and the transformed data</b>
#                 </font>
#             </div>
#
# </td>
#     </tr>
# </table>

# %%
# import your code here

np.exp(df_insurance['log_medical_cost']).skew()
# Out:
# 1.5341854555059415

# %%
sns.kdeplot(np.exp(df_insurance['log_medical_cost']))
plt.show()
